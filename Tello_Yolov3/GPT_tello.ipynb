# %% [markdown]
# # 파이썬 버전 3.9.6

# %% [markdown]
# ### 아래 라이브러리를 설치해야합니다. '#'를 지우고  pip 마다 각각 셀을 부여해 실행하세요

# %%
#!pip install opencv-python
#!pip install djitellopy
#!pip3 install keras
#!pip3 install tensorflow
# Out:
# Requirement already satisfied: opencv-python in /Users/jamessung/anaconda3/lib/python3.10/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in /Users/jamessung/anaconda3/lib/python3.10/site-packages (from opencv-python) (1.23.5)

# %% [markdown]
# ##cv2 버전 4.8.1

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.8.1

# %%
import cv2
from djitellopy import Tello
from keras.models import load_model
import numpy as np

# YOLO 모델 및 설정 파일 경로 지정
#yolo 사용할 .cfg 파일과 .weights 파일을 같게하세요 두가지 모델을 사용할 수 없습니다.
weights_path = 'yolov3-tiny.weights' #성능 최하 속도 최상
cfg_path = 'yolov3-tiny.cfg' #성능 최하 속도 최상
#weights_path = 'yolov3-spp.weights' //성능 최상 속도 최하
#cfg_path = 'yolov3-spp.cfg'//성능 최상 속도 최하
#weights_path = 'yolov3_320.weights' //성능 하 속도 상
#cfg_path = 'yolov3_320.cfg' //성능 하 속도 상
#weights_path = 'yolov3_416.weights'//성능 중 속도 중
#cfg_path = 'yolov3_416.cfg' //성능 중 속도 중
class_names_path = 'coco.names'

# 클래스 이름 불러오기
with open(class_names_path, 'r') as f:
    class_names = [line.strip() for line in f.readlines()]

# YOLO 모델 로드
net = cv2.dnn.readNet(weights_path, cfg_path)
layer_names = net.getLayerNames()
out_layers = net.getUnconnectedOutLayers().flatten()
output_layers = [layer_names[i - 1] for i in out_layers]

# Tello 드론 연결 및 초기화
tello = Tello()
tello.connect()
tello.streamon()

# 영상 캡처 및 객체 탐지 수행
while True:
    frame = tello.get_frame_read().frame
    frame_resized = cv2.resize(frame, (416, 416))

    # YOLO 객체 탐지 코드
    blob = cv2.dnn.blobFromImage(frame_resized, 1/255.0, (416, 416), swapRB=True, crop=False)
    net.setInput(blob)
    detections = net.forward(output_layers)

    # 탐지된 객체의 경계 상자를 화면에 표시
    for detection in detections[0]:
        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]
        if confidence > 0.5:
            center_x, center_y, w, h = (detection[0:4] * np.array([416, 416, 416, 416])).astype('int')
            x = int(center_x - w / 2)
            y = int(center_y - h / 2)
            cv2.rectangle(frame_resized, (x, y), (x + w, y + h), (0, 255, 0), 2)
            label = str(class_names[class_id])
            cv2.putText(frame_resized, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    cv2.imshow("Tello Object Detection", frame_resized)

    # 'q' 키를 누르면 종료
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

tello.streamoff()
cv2.destroyAllWindows()
# Out:
# /Users/jamessung/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [INFO] tello.py - 129 - Tello instance was initialized. Host: '192.168.10.1'. Port: '8889'.
# [INFO] tello.py - 438 - Send command: 'command'
# [ERROR] tello.py - 458 - 'utf-8' codec can't decode byte 0xcc in position 0: invalid continuation byte
# [INFO] tello.py - 438 - Send command: 'command'
# [INFO] tello.py - 462 - Response command: 'ok'
# [INFO] tello.py - 438 - Send command: 'streamon'
# [INFO] tello.py - 462 - Response streamon: 'ok'
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# non-existing PPS 0 referenced
# non-existing PPS 0 referenced
# decode_slice_header error
# no frame!
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 32 more times)
# error while decoding MB 17 41, bytestream -8
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 37 more times)
# error while decoding MB 58 44, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 17 more times)
# error while decoding MB 4 41, bytestream -8
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 47 more times)
# error while decoding MB 14 43, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# 2023-11-02 22:56:13.980 Python[32189:1852100] WARNING: Secure coding is automatically enabled for restorable state! However, not on all supported macOS versions of this application. Opt-in to secure coding explicitly by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState:.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 279 more times)
# error while decoding MB 53 40, bytestream -14
# error while decoding MB 34 43, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 127 more times)
# error while decoding MB 3 37, bytestream -12
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 41 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 28, bytestream 4919
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 254 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 40, bytestream 1376
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 11 more times)
# error while decoding MB 44 39, bytestream -9
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 103 more times)
# error while decoding MB 8 43, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 72 more times)
# error while decoding MB 25 39, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 6 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 38, bytestream 1500
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 59 more times)
# error while decoding MB 17 41, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 128 more times)
# left block unavailable for requested intra4x4 mode -1
# error while decoding MB 0 42, bytestream 315
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 138 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 39, bytestream 1142
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 34 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 38, bytestream 1482
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 262 more times)
# error while decoding MB 31 42, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 120 more times)
# left block unavailable for requested intra4x4 mode -1
# error while decoding MB 0 18, bytestream 1743
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 54 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 38, bytestream 211
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 153 more times)
# error while decoding MB 24 43, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 59 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 40, bytestream 180
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 30 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 20, bytestream 1808
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 92 more times)
# error while decoding MB 38 39, bytestream -5
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 15 more times)
# error while decoding MB 24 40, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 76 more times)
# error while decoding MB 41 38, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 52 more times)
# error while decoding MB 3 36, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 84 more times)
# error while decoding MB 5 39, bytestream -5
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 53 more times)
# error while decoding MB 0 39, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 20 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 40, bytestream 832
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 44 more times)
# error while decoding MB 52 38, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 124 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 18, bytestream 1011
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 73 more times)
# error while decoding MB 51 32, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 8 more times)
# error while decoding MB 34 37, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 17 more times)
# error while decoding MB 12 33, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 7 more times)
# error while decoding MB 51 34, bytestream 367
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 62 more times)
# error while decoding MB 7 38, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 115 more times)
# error while decoding MB 34 39, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 41 more times)
# error while decoding MB 25 42, bytestream -8
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 60 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 39, bytestream -1
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 19 more times)
# left block unavailable for requested intra4x4 mode -1
# error while decoding MB 0 12, bytestream 2536
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 5 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 16, bytestream 5832
# No accelerated colorspace conversion found from yuv420p to rgb24.
# error while decoding MB 58 38, bytestream 174
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 17 more times)
# error while decoding MB 36 44, bytestream -8
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 5 more times)
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 94 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 8, bytestream 6802
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 54 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 39, bytestream -2
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 84 more times)
# error while decoding MB 3 34, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 88 more times)
# error while decoding MB 6 41, bytestream -5
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 60 more times)
# error while decoding MB 29 37, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 16 more times)
# error while decoding MB 13 41, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 42 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 8, bytestream 7994
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 459 more times)
# error while decoding MB 0 23, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# left block unavailable for requested intra mode
# error while decoding MB 0 19, bytestream 3557
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 219 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 27, bytestream 3220
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 90 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 38, bytestream 13391
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 44 more times)
# error while decoding MB 17 38, bytestream -5
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 439 more times)
# error while decoding MB 0 39, bytestream -5
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 26 more times)
# error while decoding MB 3 39, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 40 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 36, bytestream 397
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 4 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 37, bytestream 1867
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 65 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 15, bytestream 4013
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 62 more times)
# error while decoding MB 23 40, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 49 more times)
# error while decoding MB 3 39, bytestream -5
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 5 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 38, bytestream 1665
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 3 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 17, bytestream 1577
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 2 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 29, bytestream 2310
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 92 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 41, bytestream 1298
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
# left block unavailable for requested intra mode
# error while decoding MB 0 41, bytestream 1390
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 5 more times)
# error while decoding MB 47 38, bytestream 271
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 38 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 42, bytestream 1489
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 81 more times)
# error while decoding MB 29 39, bytestream -5
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 161 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 24, bytestream 6655
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 70 more times)
# error while decoding MB 26 41, bytestream -6
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 73 more times)
# error while decoding MB 46 31, bytestream -12
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 28 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 28, bytestream 4657
# No accelerated colorspace conversion found from yuv420p to rgb24.
# No accelerated colorspace conversion found from yuv420p to rgb24.
#  (repeated 51 more times)
# left block unavailable for requested intra mode
# error while decoding MB 0 34, bytestream 4179
# No accelerated colorspace conversion found from yuv420p to rgb24.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jamessung/Documents/문서 /프로그래밍/파이썬/GPT_tello_Yolov3_spp/GPT_tello.ipynb 셀 6 line 3
#      <a href='vscode-notebook-cell:/Users/jamessung/Documents/%EB%AC%B8%EC%84%9C%20/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D/%ED%8C%8C%EC%9D%B4%EC%8D%AC/GPT_tello_Yolov3_spp/GPT_tello.ipynb#W5sZmlsZQ%3D%3D?line=31'>32</a> blob = cv2.dnn.blobFromImage(frame_resized, 1/255.0, (416, 416), swapRB=True, crop=False)
#      <a href='vscode-notebook-cell:/Users/jamessung/Documents/%EB%AC%B8%EC%84%9C%20/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D/%ED%8C%8C%EC%9D%B4%EC%8D%AC/GPT_tello_Yolov3_spp/GPT_tello.ipynb#W5sZmlsZQ%3D%3D?line=32'>33</a> net.setInput(blob)
# ---> <a href='vscode-notebook-cell:/Users/jamessung/Documents/%EB%AC%B8%EC%84%9C%20/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D/%ED%8C%8C%EC%9D%B4%EC%8D%AC/GPT_tello_Yolov3_spp/GPT_tello.ipynb#W5sZmlsZQ%3D%3D?line=33'>34</a> detections = net.forward(output_layers)
#      <a href='vscode-notebook-cell:/Users/jamessung/Documents/%EB%AC%B8%EC%84%9C%20/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D/%ED%8C%8C%EC%9D%B4%EC%8D%AC/GPT_tello_Yolov3_spp/GPT_tello.ipynb#W5sZmlsZQ%3D%3D?line=35'>36</a> # 탐지된 객체의 경계 상자를 화면에 표시
#      <a href='vscode-notebook-cell:/Users/jamessung/Documents/%EB%AC%B8%EC%84%9C%20/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D/%ED%8C%8C%EC%9D%B4%EC%8D%AC/GPT_tello_Yolov3_spp/GPT_tello.ipynb#W5sZmlsZQ%3D%3D?line=36'>37</a> for detection in detections[0]:
#
# KeyboardInterrupt:
